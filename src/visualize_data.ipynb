# %%
import IPython.display as display

# %%
from read_records import get_dataset
# Out:
# 2022-06-27 04:34:02.047189: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-06-27 04:34:02.047223: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
dataset_train = get_dataset('train')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/francisco/Desktop/TAA-proyecto2/src/visualize_data.ipynb Cell 3' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/francisco/Desktop/TAA-proyecto2/src/visualize_data.ipynb#ch0000002?line=0'>1</a> X, y = get_dataset('train')
#       <a href='vscode-notebook-cell:/home/francisco/Desktop/TAA-proyecto2/src/visualize_data.ipynb#ch0000002?line=1'>2</a> display.display(display.Image(data=X[0].numpy()))
#
# ValueError: too many values to unpack (expected 2)

# %%
for image, level_cat in dataset_train.take(2):
    print(f"level_cat: {level_cat}")
    print("image:")
    display.display(display.Image(data=image.numpy()))
    print("\n\n")
# Out:
# level_cat: 0
# image:
# level_cat: 0
# image:
